# %% [markdown]
# # MHWilds game data digestion notebook

# %% [markdown]
# ## General Code

# %%
# head
import urllib.request
import json
import pandas as pd
import numpy as np
import re

# helpers

# import
def json_to_df(url:str, file_structure:list=['entries']) -> pd.DataFrame:
    with urllib.request.urlopen(url) as page:
        raw = json.load(page)
    return pd.json_normalize(raw,record_path=file_structure)

# parse id - name
def parse_id_name(df_og: pd.DataFrame) -> pd.DataFrame:
    df_o = df_og.copy()
    df_o['content'] = df_o['content'].str[1]
    df_o.rename(columns={'name':'id','content':'name', 'guid':'guid_n'}, inplace=True)
    df_o['name'] = df_o['name'].str.replace('<COLOR FF0000>#Rejected#</COLOR> ','')
    return df_o[['id','name','guid_n']]

# parse id - name - description
def parse_id_name_exp(df_og: pd.DataFrame, exp_str:str='EXP') -> pd.DataFrame:
    df_o = df_og.copy()
    # pull english names
    df_o['content'] = df_o['content'].str[1]
    #separate names and descriptions
    df_1 = df_o[~df_o['name'].str.contains('EXP')].copy()
    df_2 = df_o[df_o['name'].str.contains('EXP')].copy()
    #normalize naming
    df_1.rename(columns={'name':'id','content':'name', 'guid':'guid_n'}, inplace=True)
    df_2['name'] = df_2['name'].str.replace(exp_str,'')
    df_2.rename(columns={'name':'id','content':'description', 'guid':'guid_d'}, inplace=True)
    #adjust content
    df_1['name'] = df_1['name'].str.replace('<COLOR FF0000>#Rejected#</COLOR> ','')
    df_2['description'] = df_2['description'].str.replace('<COLOR FF0000>#Rejected#</COLOR> ','')
    df_2['description'] = df_2['description'].str.replace(r'[\r\n]+', ' ', regex=True)
    df_2['description'] = df_2['description'].str.replace('<BOLD>','')
    df_2['description'] = df_2['description'].str.replace('</BOLD>','')
    #merge into final
    df_o = pd.merge(df_1[['id','guid_n','name']], df_2[['id','guid_d','description']], on='id', how='left')
    df_o.reset_index(drop=True, inplace=True)
    return df_o

# Slot digestion
def split_slots(df_og:pd.DataFrame, src_col:str='SlotLevel') -> pd.DataFrame:
    df_o = df_og.copy()
    num_slots = len(df_o[src_col].iloc[0])
    for i in range(num_slots):
        new_col = f'Slot {i+1}'
        df_o[new_col] = (df_o[src_col].str[i]
                                     .str['app.EquipDef.SlotLevel_Serializable']
                                     .str['_Value']
                                     .str.extract(r'\[(.*?)\]')
                                     .astype(int)
                        )
    df_o = df_o.drop(src_col, axis=1)
    return df_o


# skill digestion
def split_skills(df_og: pd.DataFrame,
                 skill_col: str = 'Skill',
                 level_col: str = 'SkillLevel',
                 replacement_dict: dict = None
                ) -> pd.DataFrame:
    df_o = df_og.copy()
    num_skills = len(df_o[skill_col].iloc[0])
    for i in range(num_skills):
        skill_name = f'skill_{i+1}'
        df_o[skill_name] = (df_o[skill_col].str[i]
                                           .str['app.HunterDef.Skill_Serializable']
                                           .str['_Value']
                            )
        if replacement_dict is not None:
            df_o[skill_name] = df_o[skill_name].replace(replacement_dict)
        level_name = f'skill_{i+1}_lv'
        df_o[level_name] = df_o[level_col].str[i].astype(int)
    df_o = df_o.drop([skill_col, level_col], axis=1)
    return df_o

# bracket column split
# df['hs_id'] = df['skillId'].str.extract(r'^(?:.*_)(\d+)$')
# df['hunter_id'] = df['skillId'].str.extract(r'^\[[^]]+\](.*)$')
# df['common_id'] = 'SkillCommon_' + df['skillId'].str.extract(r'\[(.*?)\]')
# df['common_id'] = df['common_id'].str.replace('-','m')

# %%
# definitions
dict_weap_names = {'LongSword':'gs',
                   'ShortSword':'sns',
                   'TwinSword':'db',
                   'Tachi':'ls',
                   'Hammer':'ham',
                   'Whistle':'hh',
                   'Lance':'lan',
                   'GunLance':'gl',
                   'SlashAxe':'swaxe',
                   'ChargeAxe':'cb',
                   'Rod':'ig',
                   'Bow':'bow',
                   'HeavyBowgun':'hbg',
                   'LightBowgun':'lbg'}

# %% [markdown]
# ## Skills
#
# ### Naming Scheme:
#
# **Attack Boost 2: ATK +5**
#
# | Attack Boost | 2 | ATK +5 |
# |-|-|-|
# | Common | Lvl | Descript. |
#
# - sc_id (skill common id) : id for skill independent of level
# - skill_id : id for specific skill & level
# - skill_category : weapon, equipment, group, etc.
# - skill_lv : level of skill

# %% [markdown]
# ### Common Skill IDs, Names, & Descriptions
# #### Source
# natives/STM/GameDesign/Text/Excel_Equip/SkillCommon.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": "SkillCommon_m1961116288",
#     "content": [
#         "Rapid Morph",
#     "name": "SkillCommon_EXPm1961116288",
#     "content": [
#         "Increases switch speed and power\r\nfor switch axes and charge blades.",
# ```
# </details>
#
# #### df_skill_common_ids
# |common_id|guid_n|name|guid_d|description|
# |-|-|-|-|-|
# |SkillCommon_0|82d0863d-8ea5-4106-9392-a8b7575f6b9f|SkillCommon_0|ab11e7f5-8b70-4dff-a0ac-f9643ef55e6a|SkillCommon_EXP0|
# |SkillCommon_1|c5243424-047c-40cf-a6f4-69e9d3ae860f|Attack Boost|38b4b21e-d241-4c08-ae35-cff0632574e2|Increases attack power.|
# |SkillCommon_m2096489472|c4dc2439-1d42-4ef4-bca9-07be35f4bebd|Critical Eye|768c9e10-dfe1-4373-937c-d6376e92a26a|Increases affinity.|
# |SkillCommon_m1607763456|6e7e9e83-16b1-4bf6-92e9-98eff98d85ac|Critical Boost|671c0922-1fe5-4c78-aac4-213ea807daa1|Increases the damage of critical hits.|
# |SkillCommon_313598432|b09b9e70-7243-45c5-86e3-158ed24004e8|Critical Element|f1506057-3237-400b-a7aa-4f6619236f11|Increases elemental damage (fire, water, thunder, ice, dragon) when landing critical hits.|
#
# #### Dicts
# - dict_common_guid_names { guid_n : name }
# - dict_common_guid_desc { guid_d : description }
# - dict_common_id_names { sc_id : name }

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/SkillCommon.msg.23.json'

df = json_to_df(url,['entries'])
df = parse_id_name_exp(df,'EXP')

#dicts
dict_common_guid_names = dict(zip(df['guid_n'], df['name']))
dict_common_guid_desc = dict(zip(df['guid_d'], df['description']))
dict_common_id_names = dict(zip(df['id'], df['name']))

#format skill common id
# df['id'] = df['id'].str.replace('SkillCommon_','')
# df['id'] = df['id'].str.replace('m','-')
# df.rename(columns={'id':'skill_common_id'}, inplace=True)

df.rename(columns={'id':'common_id'}, inplace=True)

df_skill_common_ids = df.copy()

df_skill_common_ids.head()
# df_skill_common.to_excel('text skill common.xlsx')
# Out:
#                  common_id                                guid_n  \
# 0            SkillCommon_0  82d0863d-8ea5-4106-9392-a8b7575f6b9f
# 1            SkillCommon_1  c5243424-047c-40cf-a6f4-69e9d3ae860f
# 2  SkillCommon_m2096489472  c4dc2439-1d42-4ef4-bca9-07be35f4bebd
# 3  SkillCommon_m1607763456  6e7e9e83-16b1-4bf6-92e9-98eff98d85ac
# 4    SkillCommon_313598432  b09b9e70-7243-45c5-86e3-158ed24004e8
#
#                name                                guid_d  \
# 0     SkillCommon_0  ab11e7f5-8b70-4dff-a0ac-f9643ef55e6a
# 1      Attack Boost  38b4b21e-d241-4c08-ae35-cff0632574e2
# 2      Critical Eye  768c9e10-dfe1-4373-937c-d6376e92a26a
# 3    Critical Boost  671c0922-1fe5-4c78-aac4-213ea807daa1
# 4  Critical Element  f1506057-3237-400b-a7aa-4f6619236f11
#
#                                          description
# 0                                   SkillCommon_EXP0
# 1                            Increases attack power.
# 2                                Increases affinity.
# 3             Increases the damage of critical hits.
# 4  Increases elemental damage (fire, water, thund...

# %% [markdown]
# ### Specific Skill IDs & Descriptions
#
# #### Source
# natives/STM/GameDesign/Text/Excel_Equip/Skill.msg.23.json
# <details>
#
# ```
# "entries": [
#     {
#         "name": "Skill_488",
#       "guid": "95f8239f-d0c1-4120-b3fb-37378e8875f5",
#       ...
#       "content": [
#         "<COLOR FF0000>#Rejected#</COLOR> Skill_488",
#         "<COLOR FF0000>#Rejected#</COLOR> Skill_488",]
#     },
#     {
#       "name": "Skill_EXP488",
#       "guid": "f72a7bc8-58c8-4550-afc3-2450a5b463c2",
#       ...
#       "content": [
#         "会心攻撃時のダメージ倍率を\r\n１．３７倍に強化する",
#         "Increases damage dealt\r\nby critical hits to 37%.",
#       ]
#     },
# ```
# </details>
#
# #### df_skill_spec_ids
# |spec_id|guid_n|name|guid_d|description|
# |-|-|-|-|-|
# |Skill_1|f7457609-c698-44dc-a87c-3013a81fe34f|Skill_1|3b08702a-e4a1-4de4-b7db-f5897fef1c4b|Skill_EXP1|
# |Skill_2|824fa7e2-6344-4f5d-a140-0d411ccc674d|Skill_2|96e65c81-c4a1-4fb0-aea4-c256200cda88|Attack +3|
# |Skill_3|c3858b4a-0f53-4739-ade5-ddf1c08497ad|Skill_3|b97ead47-2c69-436f-ab9d-4f9059ec151f|Attack +5|
# |Skill_4|2a36d1c4-d599-4b2d-8385-47ebef1df235|Skill_4|9d878426-10dd-4506-9259-6548d4c59735|Attack +7|
# |Skill_5|85873022-2c20-4f4a-9e13-6c2e1275918a|Skill_5|86a03b9f-c136-414c-8fe5-501b6c4b6b73|Attack +2% Bonus: +8|
#
# #### Dicts
# - dict_spec_guid_names: { guid_n : name }
# - dict_spec_guid_desc: { guid_d : description }

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/Skill.msg.23.json'

df = json_to_df(url,['entries'])
df = parse_id_name_exp(df,'EXP')

#dicts
dict_spec_guid_names = dict(zip(df['guid_n'], df['name']))
dict_spec_guid_desc = dict(zip(df['guid_d'], df['description']))

#format skill ids
# df['id'] = df['id'].str.replace('Skill_','')
df.rename(columns={'id':'spec_id'}, inplace=True)

df_skill_spec_ids = df.copy()

# df_1.head()
df_skill_spec_ids.head()
# df_skills.to_excel('text skill.xlsx')
# Out:
#    spec_id                                guid_n     name  \
# 0  Skill_1  f7457609-c698-44dc-a87c-3013a81fe34f  Skill_1
# 1  Skill_2  824fa7e2-6344-4f5d-a140-0d411ccc674d  Skill_2
# 2  Skill_3  c3858b4a-0f53-4739-ade5-ddf1c08497ad  Skill_3
# 3  Skill_4  2a36d1c4-d599-4b2d-8385-47ebef1df235  Skill_4
# 4  Skill_5  85873022-2c20-4f4a-9e13-6c2e1275918a  Skill_5
#
#                                  guid_d           description
# 0  3b08702a-e4a1-4de4-b7db-f5897fef1c4b            Skill_EXP1
# 1  96e65c81-c4a1-4fb0-aea4-c256200cda88             Attack +3
# 2  b97ead47-2c69-436f-ab9d-4f9059ec151f             Attack +5
# 3  9d878426-10dd-4506-9259-6548d4c59735             Attack +7
# 4  86a03b9f-c136-414c-8fe5-501b6c4b6b73  Attack +2% Bonus: +8

# %% [markdown]
# ### Common Skills
#
# #### Source
# natives/STM/GameDesign/Common/Equip/SkillCommonData.user.3.json
# <details>
#
# ```
# "app.user_data.SkillCommonData": {
#     "_Values": [
#         {
#             "app.user_data.SkillCommonData.cData": {
#                 "_Index": 4,
#                 "_skillId": "[-181127504]HunterSkill_028",
#                 "_skillType": "[441208832]NONE",
#                 "_skillCategory": "[3]WEAPON",
#                 "_SkillIconType": "[1]SKILL_0000",
#                 "_skillName": "b759c7ca-775e-4779-ab53-f94bf2962305",
#                 "_skillExplain": "7c1468b7-0445-4dc1-acb2-6d5bf228f9f5",
#                 "_SortId": 4
#             }
#         },
# ```
# </details>
#
# #### df_common_skills
# |name|category|description|SkillIconType|common_hunter_id|common_id|hunter_id|SortId|
# |-|-|-|-|-|-|-|-|
# |SkillCommon_0|[0]EQUIP|SkillCommon_EXP0|[1]SKILL_0000|[0]NONE|SkillCommon_0|NONE|0|
# |Attack Boost|[3]WEAPON|Increases attack power.|[1]SKILL_0000|[1]HunterSkill_000|SkillCommon_1|HunterSkill_000|1|
# |Resentment|[0]EQUIP|Increases attack when you have recoverable damage (the red portion of your Health Gauge).|[1]SKILL_0000|[1359821952]HunterSkill_060|SkillCommon_1359821952|HunterSkill_060|2|
# |Adrenaline Rush|[0]EQUIP|Temporarily increases attack power after executing a perfectly-timed evade just as a monster attacks.|[1]SKILL_0000|[1174975744]HunterSkill_115|SkillCommon_1174975744|HunterSkill_115|3|
# |Offensive Guard|[3]WEAPON|Temporarily increases attack power after executing a perfectly-timed guard.|[1]SKILL_0000|[-181127504]HunterSkill_028|SkillCommon_m181127504|HunterSkill_028|4|
#
# #### Dicts
# - dict_common_hunter_name: { common_hunter_id : name }

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/SkillCommonData.user.3.json'

df = json_to_df(url,['app.user_data.SkillCommonData', '_Values'])
df.columns = df.columns.str.replace('app.user_data.SkillCommonData.cData._','')

#split ids
# df['hs_id'] = df['skillId'].str.extract(r'^(?:.*_)(\d+)$')
df['hunter_id'] = df['skillId'].str.extract(r'^\[[^]]+\](.*)$')
df['common_id'] = 'SkillCommon_' + df['skillId'].str.extract(r'\[(.*?)\]')
df['common_id'] = df['common_id'].str.replace('-','m')

df['skillName'] = df['skillName'].replace(dict_common_guid_names)
df['skillExplain'] = df['skillExplain'].replace(dict_common_guid_desc)

df_common_skills = df[['skillName','skillCategory','skillExplain','SkillIconType','skillId','common_id','hunter_id','SortId']].copy()
df.reset_index(drop=True, inplace=True)

df_common_skills.rename(columns={'skillName':'name',
                   'skillExplain':'description',
                   'skillCategory':'category',
                   'skillId':'common_hunter_id'}, inplace=True)

#dicts
dict_common_hunter_name = dict(zip(df_common_skills['common_hunter_id'],df_common_skills['name']))

df_common_skills.head()
# df_common_skills.to_excel('common_skills.xlsx')
# Out:
#               name   category  \
# 0    SkillCommon_0   [0]EQUIP
# 1     Attack Boost  [3]WEAPON
# 2       Resentment   [0]EQUIP
# 3  Adrenaline Rush   [0]EQUIP
# 4  Offensive Guard  [3]WEAPON
#
#                                          description  SkillIconType  \
# 0                                   SkillCommon_EXP0  [1]SKILL_0000
# 1                            Increases attack power.  [1]SKILL_0000
# 2  Increases attack when you have recoverable dam...  [1]SKILL_0000
# 3  Temporarily increases attack power after execu...  [1]SKILL_0000
# 4  Temporarily increases attack power after execu...  [1]SKILL_0000
#
#               common_hunter_id               common_id        hunter_id  \
# 0                      [0]NONE           SkillCommon_0             NONE
# 1           [1]HunterSkill_000           SkillCommon_1  HunterSkill_000
# 2  [1359821952]HunterSkill_060  SkillCommon_1359821952  HunterSkill_060
# 3  [1174975744]HunterSkill_115  SkillCommon_1174975744  HunterSkill_115
# 4  [-181127504]HunterSkill_028  SkillCommon_m181127504  HunterSkill_028
#
#    SortId
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4

# %% [markdown]
# ### Specific Skill Detail Relations
# #### Source
# natives/STM/GameDesign/Common/Equip/SkillData.user.3.json
# <details>
#
# ```
# "app.user_data.SkillData": {
#     "_Values": [
#         {
#             "app.user_data.SkillData.cData": {
#                 "_Index": 3,
#                 "_dataId": 4,
#                 "_skillId": "[1]HunterSkill_000",
#                 "_SkillLv": 3,
#                 "_skillName": "2a36d1c4-d599-4b2d-8385-47ebef1df235",
#                 "_skillExplain": "9d878426-10dd-4506-9259-6548d4c59735",
#                 "_openSkill": [
#                     "[1]HunterSkill_000",
#                     "[0]NONE",
#                     "[0]NONE",
#                     "[0]NONE",
#                     "[0]NONE"
#                 ],
#                 "_value": [
#                     100,
#                     7,
#                     0,
#                     0
#                 ]
#             }
#         },
# ```
# </details>
#
# #### df_spec_skills
# |Index|spec_id|common_name|SkillLv|spec_name|description|value|os1|os2|os3|os4|os5|
# |-|-|-|-|-|-|-|-|-|-|-|-|
# |0|Skill_1|SkillCommon_0|0|Skill_1|Skill_EXP1|[0, 0, 0, 0]|SkillCommon_0|SkillCommon_0|SkillCommon_0|SkillCommon_0|SkillCommon_0|
# |1|Skill_2|Attack Boost|1|Attack Boost 1|Attack +3|[100, 3, 0, 0]|Attack Boost|SkillCommon_0|SkillCommon_0|SkillCommon_0|SkillCommon_0|
# |2|Skill_3|Attack Boost|2|Attack Boost 2|Attack +5|[100, 5, 0, 0]|Attack Boost|SkillCommon_0|SkillCommon_0|SkillCommon_0|SkillCommon_0|
# |3|Skill_4|Attack Boost|3|Attack Boost 3|Attack +7|[100, 7, 0, 0]|Attack Boost|SkillCommon_0|SkillCommon_0|SkillCommon_0|SkillCommon_0|
# |4|Skill_5|Attack Boost|4|Attack Boost 4|Attack +2% Bonus: +8|[102, 8, 0, 0]|Attack Boost|SkillCommon_0|SkillCommon_0|SkillCommon_0|SkillCommon_0|
#
#
# #### Dicts
#
# - dict_backfill = dict(zip(df_1['os1'],df_1['spec_name']))

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/SkillData.user.3.json'

# with urllib.request.urlopen(url) as page:
#     raw = json.load(page)
# df = pd.json_normalize(raw, record_path=['app.user_data.SkillData', '_Values'])

df = json_to_df(url,['app.user_data.SkillData', '_Values'])
df.columns = df.columns.str.replace('app.user_data.SkillData.cData._','')

#split openSkill
df[['os1','os2','os3','os4','os5']] = pd.DataFrame(df['openSkill'].tolist(), index=df.index)

#replace os data
df[['os1','os2','os3','os4','os5']] = df[['os1','os2','os3','os4','os5']].replace(dict_common_hunter_name)

#recombine
df = df.drop('openSkill', axis=1)

#data replacement
df['skillName'] = df['skillName'].replace(dict_spec_guid_names)
df['skillExplain'] = df['skillExplain'].replace(dict_spec_guid_desc)
df['skillId'] = df['skillId'].replace(dict_common_hunter_name)

# mask = df['os1'].str.contains('_')
# df_1 = df.loc[mask]
# dict_backfill = dict(zip(df_1['os1'],df_1['spec_name']))

# specific skill name fill blanks with generics
mask = df['skillName'].str.contains('Skill_') & ~df['skillId'].str.contains('SkillCommon_')
df.loc[mask, 'skillName'] = df.loc[mask, 'skillId'] + ' ' + df.loc[mask, 'SkillLv'].astype(str)

#adjust specific skill id
df['dataId'] = 'Skill_' + df['dataId'].astype(str)

df.rename(columns={'dataId':'spec_id',
                   'skillId':'common_name',
                   'skillExplain':'description',
                   'skillName':'spec_name'}, inplace=True)
df_spec_skills = df.copy()
df_spec_skills.reset_index(drop=True, inplace=True)

df_spec_skills.head()
# df_spec_skills.to_excel('specific skills.xlsx')
# Out:
#    Index  spec_id    common_name  SkillLv       spec_name  \
# 0      0  Skill_1  SkillCommon_0        0         Skill_1
# 1      1  Skill_2   Attack Boost        1  Attack Boost 1
# 2      2  Skill_3   Attack Boost        2  Attack Boost 2
# 3      3  Skill_4   Attack Boost        3  Attack Boost 3
# 4      4  Skill_5   Attack Boost        4  Attack Boost 4
#
#             description           value            os1            os2  \
# 0            Skill_EXP1    [0, 0, 0, 0]  SkillCommon_0  SkillCommon_0
# 1             Attack +3  [100, 3, 0, 0]   Attack Boost  SkillCommon_0
# 2             Attack +5  [100, 5, 0, 0]   Attack Boost  SkillCommon_0
# 3             Attack +7  [100, 7, 0, 0]   Attack Boost  SkillCommon_0
# 4  Attack +2% Bonus: +8  [102, 8, 0, 0]   Attack Boost  SkillCommon_0
#
#              os3            os4            os5
# 0  SkillCommon_0  SkillCommon_0  SkillCommon_0
# 1  SkillCommon_0  SkillCommon_0  SkillCommon_0
# 2  SkillCommon_0  SkillCommon_0  SkillCommon_0
# 3  SkillCommon_0  SkillCommon_0  SkillCommon_0
# 4  SkillCommon_0  SkillCommon_0  SkillCommon_0

# %% [markdown]
# ### Consolidation
# #### Backfill common name data

# %%
# common names
mask = df_spec_skills['os1'].str.contains('SkillCommon_')
df = df_spec_skills.loc[mask]
dict_ = dict(zip(df['os1'],df['spec_name']))

df_skill_common_ids['name'] = df_skill_common_ids['name'].replace(dict_)
df_skill_common_ids['name'] = df_skill_common_ids['name'].str.replace(' II','')

# forwardfill common skills
dict_ = dict(zip(df_skill_common_ids['common_id'],df_skill_common_ids['name']))
df_common_skills['name'] = df_common_skills['name'].replace(dict_)

# HunterSkill recover
mask = df_spec_skills['os1'].str.contains('HunterSkill_')
df = df_spec_skills.loc[mask]
df = df.iloc[1:]
df = df[['spec_name','os1']]
df.columns = ['name','common_hunter_id']
df['hunter_id'] = df['common_hunter_id'].str.extract(r'^\[[^]]+\](.*)$')
df['common_id'] = 'SkillCommon_' + df['common_hunter_id'].str.extract(r'\[(.*?)\]')
df['common_id'] = df['common_id'].str.replace('-','m')
df['description'] = 'SkillCommon_EXP' + df['common_hunter_id'].str.extract(r'\[(.*?)\]')
df['description'] = df['description'].str.replace('-','m')
df_common_skills = pd.concat([df_common_skills,df], ignore_index=True)
df_common_skills['name'] = df_common_skills['name'].str.replace(' II','')


# df_skill_common_ids
df_common_skills.head()
# df_common_skills.to_excel('common skill.xlsx')
# Out:
#               name   category  \
# 0          Skill_1   [0]EQUIP
# 1     Attack Boost  [3]WEAPON
# 2       Resentment   [0]EQUIP
# 3  Adrenaline Rush   [0]EQUIP
# 4  Offensive Guard  [3]WEAPON
#
#                                          description  SkillIconType  \
# 0                                   SkillCommon_EXP0  [1]SKILL_0000
# 1                            Increases attack power.  [1]SKILL_0000
# 2  Increases attack when you have recoverable dam...  [1]SKILL_0000
# 3  Temporarily increases attack power after execu...  [1]SKILL_0000
# 4  Temporarily increases attack power after execu...  [1]SKILL_0000
#
#               common_hunter_id               common_id        hunter_id  \
# 0                      [0]NONE           SkillCommon_0             NONE
# 1           [1]HunterSkill_000           SkillCommon_1  HunterSkill_000
# 2  [1359821952]HunterSkill_060  SkillCommon_1359821952  HunterSkill_060
# 3  [1174975744]HunterSkill_115  SkillCommon_1174975744  HunterSkill_115
# 4  [-181127504]HunterSkill_028  SkillCommon_m181127504  HunterSkill_028
#
#    SortId
# 0     0.0
# 1     1.0
# 2     2.0
# 3     3.0
# 4     4.0

# %% [markdown]
# #### Backfill specific name data

# %%
dict_ = dict(zip(df_spec_skills['spec_id'],df_spec_skills['spec_name']))
df_skill_spec_ids['name'] = df_skill_spec_ids['name'].replace(dict_)

df_skill_spec_ids.head()
# Out:
#    spec_id                                guid_n            name  \
# 0  Skill_1  f7457609-c698-44dc-a87c-3013a81fe34f         Skill_1
# 1  Skill_2  824fa7e2-6344-4f5d-a140-0d411ccc674d  Attack Boost 1
# 2  Skill_3  c3858b4a-0f53-4739-ade5-ddf1c08497ad  Attack Boost 2
# 3  Skill_4  2a36d1c4-d599-4b2d-8385-47ebef1df235  Attack Boost 3
# 4  Skill_5  85873022-2c20-4f4a-9e13-6c2e1275918a  Attack Boost 4
#
#                                  guid_d           description
# 0  3b08702a-e4a1-4de4-b7db-f5897fef1c4b            Skill_EXP1
# 1  96e65c81-c4a1-4fb0-aea4-c256200cda88             Attack +3
# 2  b97ead47-2c69-436f-ab9d-4f9059ec151f             Attack +5
# 3  9d878426-10dd-4506-9259-6548d4c59735             Attack +7
# 4  86a03b9f-c136-414c-8fe5-501b6c4b6b73  Attack +2% Bonus: +8

# %% [markdown]
# #### milestone output

# %%
df_common_skills.to_excel('common skill.xlsx')
df_spec_skills[['spec_id','common_name','SkillLv','spec_name','description']].to_excel('specific skills.xlsx')

# %% [markdown]
# ## Armors

# %% [markdown]
# ### Armor IDs
# natives/STM/GameDesign/Text/Excel_Equip/Armor.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": "Armor_ID00117",
#     "content": [
#         "G. Ebony Helm",
#     "name": "Armor_EXPID00117",
#     "content": [
#         "Head armor made from Guardian\r\nEbony Odogaron spoils. To don it\r\nis to be seized by unspeakable\r\ncravings.",
# ```
# </details>
#
# #### df

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/Armor.msg.23.json'

df = json_to_df(url,['entries'])
df = parse_id_name_exp(df,'EXP')

#dicts
# dict_common_guid_names = dict(zip(df['guid_n'], df['name']))
# dict_common_guid_desc = dict(zip(df['guid_d'], df['description']))
# dict_common_id_names = dict(zip(df['id'], df['name']))

df.rename(columns={'id':'armor_id'}, inplace=True)

df_armor_ids = df.copy()

df_armor_ids.head()
# Out:
#         armor_id                                guid_n            name  \
# 0  Armor_ID00001  5383ad5c-ca4d-4faa-8583-da37b738b483       Hope Mask
# 1  Armor_ID00002  8a8eaf84-d6f0-4983-9a1b-a6e1455116bf       Hope Mail
# 2  Armor_ID00003  8b2913a9-14b2-4dc7-a1f1-933237a9c633  Hope Vambraces
# 3  Armor_ID00004  343b29da-c830-4514-8395-bf72db6ec994       Hope Coil
# 4  Armor_ID00005  beb67c1e-8d41-43cc-881e-3a4157be0421    Hope Greaves
#
#                                  guid_d  \
# 0  e54ca422-c8ef-4c71-bd0e-3e5ffbbe3c34
# 1  1f55f364-cb30-4d2b-a66a-2e4b17cf9c7b
# 2  d2bb221d-8d76-4d46-82a2-d202d699bc56
# 3  72f93eec-b3d7-45cd-b9ed-353f4e9c9490
# 4  cd257a97-c8f2-40b4-8049-9de1293fa3ed
#
#                                          description
# 0  Armor crafted specifically for members of the ...
# 1  Armor crafted specifically for members of the ...
# 2  Armor crafted specifically for members of the ...
# 3  Armor crafted specifically for members of the ...
# 4  Armor crafted specifically for members of the ...

# %% [markdown]
# ### Armor Series
# natives/STM/GameDesign/Text/Excel_Equip/ArmorSeries.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": "ArmorSeries_12",
#     "content": [
#         "Bulaqchi",
# ```
# </details>

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/ArmorSeries.msg.23.json'

df = json_to_df(url,['entries'])

# pull english names
df['content'] = df['content'].str[1]

df.rename(columns={'name':'series_id',
                   'content':'name'}, inplace=True)

df_armor_series = df[['series_id','guid','name']].copy()

df_armor_series.head()
# Out:
#        series_id                                  guid       name
# 0  ArmorSeries_0  ddac217a-52a5-40b3-814c-a310e137df9b          -
# 1  ArmorSeries_2  dd658f22-a56c-4128-b500-0fd7b9fb5dd0       Hope
# 2  ArmorSeries_3  ca4f1245-b46f-4d91-b091-c967f4069a61    Leather
# 3  ArmorSeries_4  b39c4924-3921-4fbd-a468-0f69540e9020  Chainmail
# 4  ArmorSeries_5  f23c8723-53cf-4ee3-8f7c-cbda56a555af       Bone

# %% [markdown]
# ### Armor Data
#
# #### Source
# natives/STM/GameDesign/Common/Equip/ArmorData.user.3.json
# <details>
#
# ```
# "app.user_data.ArmorData": {
#     "_Values": [
#     {
#         "app.user_data.ArmorData.cData": {
#             "_Index": 11,
#             "_DataValue": 12,
#             "_Series": {
#                 "app.ArmorDef.SERIES_Serializable": {
#                     "_Value": "[4]ID_003"
#                 }
#             },
#             "_PartsType": {
#                 "app.ArmorDef.ARMOR_PARTS_Serializable": {
#                     "_Value": "[1]BODY"
#                 }
#             },
#             "_Name": "efcf7b75-8990-45d8-afff-9175814887d2",
#             "_Explain": "a476e4ab-9039-4488-8637-8b2d71e0b549",
#             "_Defense": 2,
#             "_Resistance": [
#                 0,
#                 2,
#                 0,
#                 0,
#                 0
#             ],
#             "_SlotLevel": [
#                 {
#                     "app.EquipDef.SlotLevel_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.EquipDef.SlotLevel_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.EquipDef.SlotLevel_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 }
#             ],
#             "_Skill": [
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[595870656]HunterSkill_090"
#                     }
#                 },
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 },
#                 {
#                     "app.HunterDef.Skill_Serializable": {
#                         "_Value": "[0]NONE"
#                     }
#                 }
#             ],
#             "_SkillLevel": [
#                 0,
#                 0,
#                 1,
#                 0,
#                 0,
#                 0,
#                 0
#             ]
#         }
#     },
# ```
# </details>
#
# #### df_armor
# |series_combo_id|series_name|part|name|Defense|Fire|Water|Thunder|Ice|Dragon|slot_1_lv|slot_2_lv|slot_3_lv|series_skill|group_skill|skill_1|skill_1_lv|skill_2|skill_2_lv|skill_3|skill_3_lv|skill_4|skill_4_lv|skill_5|skill_5_lv|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|
# |[2]ID_001|Hope|[0]HELM|Hope Mask|2|1|0|1|0|0|0|0|0|Skill_1|Skill_1|Stun Resistance|1|Skill_1|0|Skill_1|0|Skill_1|0|Skill_1|0|
# |[2]ID_001|Hope|[1]BODY|Hope Mail|2|1|0|1|0|0|0|0|0|Skill_1|Skill_1|Divine Blessing|1|Skill_1|0|Skill_1|0|Skill_1|0|Skill_1|0|
# |[2]ID_001|Hope|[2]ARM|Hope Vambraces|2|1|0|1|0|0|0|0|0|Skill_1|Skill_1|Divine Blessing|1|Skill_1|0|Skill_1|0|Skill_1|0|Skill_1|0|
# |[2]ID_001|Hope|[3]WAIST|Hope Coil|2|1|0|1|0|0|0|0|0|Skill_1|Skill_1|Stun Resistance|1|Skill_1|0|Skill_1|0|Skill_1|0|Skill_1|0|
# |[2]ID_001|Hope|[4]LEG|Hope Greaves|2|1|0|1|0|0|0|0|0|Skill_1|Skill_1|Divine Blessing|1|Skill_1|0|Skill_1|0|Skill_1|0|Skill_1|0|

# %%
# Armor
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/ArmorData.user.3.json'

df = json_to_df(url,['app.user_data.ArmorData','_Values'])

df.columns = df.columns.str.replace('app.user_data.ArmorData.cData._','')

# working rename
df.rename(columns={'Series.app.ArmorDef.SERIES_Serializable._Value':'series_serial',
                   'PartsType.app.ArmorDef.ARMOR_PARTS_Serializable._Value':'part'}, inplace=True)
# df['Series'] = df['Series.app.ArmorDef.SERIES_Serializable._Value'].str.extract(r'\](.*)', expand=False)
# df['Part'] = df['PartsType.app.ArmorDef.ARMOR_PARTS_Serializable._Value'].str.extract(r'\](.*)', expand=False)

# resistances
df[['Fire Res','Water Res','Thunder Res','Ice Res','Dragon Res']] = pd.DataFrame(df['Resistance'].tolist(), index=df.index)
df = df.drop('Resistance', axis=1)

# slots
df = split_slots(df)

# skills
df['Set Bonus'] = df['Skill'].str[0].str['app.HunterDef.Skill_Serializable'].str['_Value']
df['Group Skill'] = df['Skill'].str[1].str['app.HunterDef.Skill_Serializable'].str['_Value']
df['Skill 1'] = df['Skill'].str[2].str['app.HunterDef.Skill_Serializable'].str['_Value']
df['Skill 2'] = df['Skill'].str[3].str['app.HunterDef.Skill_Serializable'].str['_Value']
df['Skill 3'] = df['Skill'].str[4].str['app.HunterDef.Skill_Serializable'].str['_Value']
df['Skill 4'] = df['Skill'].str[5].str['app.HunterDef.Skill_Serializable'].str['_Value']
df['Skill 5'] = df['Skill'].str[6].str['app.HunterDef.Skill_Serializable'].str['_Value']
df = df.drop('Skill', axis=1)

# skill levels
df[['Set Bonus LV','Group Skill LV','Skill 1 LV','Skill 2 LV','Skill 3 LV','Skill 4 LV','Skill 5 LV']] = pd.DataFrame(df['SkillLevel'].tolist(), index=df.index)
df = df.drop('SkillLevel', axis=1)

# skill replace
dict_ = dict(zip(df_common_skills['common_hunter_id'], df_common_skills['name']))
df[['Set Bonus','Group Skill','Skill 1','Skill 2','Skill 3','Skill 4','Skill 5']] = df[['Set Bonus','Group Skill','Skill 1','Skill 2','Skill 3','Skill 4','Skill 5']].replace(dict_)

#series_id & series_id_alt split
# df['series_id'] = 'ArmorSeries_' + df['series_serial'].str.extract(r'\[(.*?)\]')
# df['series_id'] = df['series_id'].str.replace('-','m')
# df['series_alt_id'] = df['series_serial'].str.extract(r'^\[[^]]+\](.*)$')

# series_serial to Series Name
df['Series Name'] = 'ArmorSeries_' + df['series_serial'].str.extract(r'\[(.*?)\]')
df['Series Name'] = df['Series Name'].str.replace('-','m')
dict_ = dict(zip(df_armor_series['series_id'],df_armor_series['name']))
df['Series Name'] = df['Series Name'].replace(dict_)

#calc unique ID:Series column
df['ID:Series'] = df['series_serial'].str.extract(r'^\[[^]]+\](.*)$')
df['ID:Series'] = df['ID:Series'] + ': ' + df['Series Name']

# name and description replace
dict_ = dict(zip(df_armor_ids['guid_n'], df_armor_ids['name']))
df['Name'] = df['Name'].replace(dict_)
dict_ = dict(zip(df_armor_ids['guid_d'], df_armor_ids['description']))
df['Explain'] = df['Explain'].replace(dict_)

# Part column format
df['part'] = df['part'].str.extract(r'^\[[^]]+\](.*)$')
# df['part'] = df['part'].str.capitalize()

# column rename
df.rename(columns={
                #    'Name':'name',
                   'Explain':'description',
                   'ID:Series':'Series',
                   'part':'Part Type'},inplace=True)

# reorder and remove columns
df_armor=df[['Name',
             'Index',
             'series_serial',
             'Series',
             'Part Type',
             'Defense',
             'Fire Res','Water Res','Thunder Res','Ice Res','Dragon Res',
             'Slot 1','Slot 2','Slot 3',
             'Set Bonus','Set Bonus LV',
             'Group Skill','Group Skill LV',
             'Skill 1','Skill 1 LV',
             'Skill 2','Skill 2 LV',
             'Skill 3','Skill 3 LV',
             'Skill 4','Skill 4 LV',
             'Skill 5','Skill 5 LV']].copy()
df_armor.reset_index(drop=True, inplace=True)

df_armor.head()
df_armor.to_excel("wilds_armor.xlsx")

# %% [markdown]
# ### Backfill Armor Series

# %%
df_1 = df_armor[['series_serial']].copy()
df_1['series_id'] = 'ArmorSeries_' + df_1['series_serial'].str.extract(r'\[(.*?)\]')
df_1['series_id'] = df_1['series_id'].str.replace('-','m')
df_1['series_alt_id'] = df_1['series_serial'].str.extract(r'^\[[^]]+\](.*)$')
df_1 = df_1.drop_duplicates(subset='series_id')

df_armor_series = pd.merge(df_armor_series, df_1, on='series_id', how='left')
df_armor_series.reset_index(drop=True, inplace=True)

df_armor_series.head()
# Out:
#        series_id                                  guid       name  \
# 0  ArmorSeries_0  ddac217a-52a5-40b3-814c-a310e137df9b          -
# 1  ArmorSeries_2  dd658f22-a56c-4128-b500-0fd7b9fb5dd0       Hope
# 2  ArmorSeries_3  ca4f1245-b46f-4d91-b091-c967f4069a61    Leather
# 3  ArmorSeries_4  b39c4924-3921-4fbd-a468-0f69540e9020  Chainmail
# 4  ArmorSeries_5  f23c8723-53cf-4ee3-8f7c-cbda56a555af       Bone
#
#   series_serial series_alt_id
# 0           NaN           NaN
# 1     [2]ID_001        ID_001
# 2     [3]ID_002        ID_002
# 3     [4]ID_003        ID_003
# 4     [5]ID_004        ID_004

# %% [markdown]
# ### Armor Series Other
# #### Source
# natives/STM/GameDesign/Common/Equip/ArmorSeriesData.user.3.json
# <details>
#
# ```
# "app.user_data.ArmorSeriesData": {
#     "_Values": [
#         {
#             "app.user_data.ArmorSeriesData.cData": {
#                 "_Index": 36,
#                 "_Series": {
#                     "app.ArmorDef.SERIES_Serializable": {
#                         "_Value": "[-1830990336]ID_061"
#                     }
#                 },
#                 "_Name": "daf67436-95a6-4d7f-8879-30070c46bdf8",
#                 "_ModelVariety": {
#                     "app.ArmorDef.MODEL_VARIETY_Serializable": {
#                         "_Value": "[0]BOTH"
#                     }
#                 },
#                 "_ModId": 4,
#                 "_ModSubMaleId": 0,
#                 "_ModSubFemaleId": 1,
#                 "_SortId": 36,
#                 "_Rare": {
#                     "app.ItemDef.RARE_Serializable": {
#                         "_Value": "[14]RARE4"
#                     }
#                 },
#                 "_Price": 2500,
#                 "_Color": {
#                     "app.ArmorDef.ARMOR_COLOR_TYPE_Serializable": {
#                         "_Value": "[-993752576]Type02"
#                     }
#                 },
#                 "_IsOneSet": false
#             }
#         },
# ```
# </details>
#
# #### df -

# %%
# Calc helper columns
df_armor_dropdowns = pd.DataFrame.from_dict(df_armor.groupby('Part Type')['Name'].apply(list).to_dict(), orient='index').reindex(['HELM', 'BODY', 'ARM', 'WAIST', 'LEG']).T
df_armor_dropdowns.head()
# df_armor_dropdowns.to_excel('armor dropdowns.xlsx')
# Out:
#                  HELM             BODY                ARM            WAIST  \
# 0           Hope Mask        Hope Mail     Hope Vambraces        Hope Coil
# 1    Leather Headgear     Leather Vest     Leather Gloves     Leather Belt
# 2  Chainmail Headgear   Chainmail Vest   Chainmail Gloves   Chainmail Belt
# 3           Bone Helm        Bone Mail     Bone Vambraces        Bone Coil
# 4      Bulaqchi Specs  Chatacabra Mail  Talioth Vambraces  Chatacabra Coil
#
#                   LEG
# 0        Hope Greaves
# 1       Leather Pants
# 2     Chainmail Pants
# 3        Bone Greaves
# 4  Chatacabra Greaves

# %% [markdown]
# ## Decos
# ### Deco IDs
# #### Source
# natives/STM/GameDesign/Text/Excel_Equip/Accessory.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": "Accessory_ACC_1179637760",
#     "content": [
#         "Gambit Jewel II [2]",
#     "name": "Accessory_ACC_EXP_19401228",
#     "content": [
#         "A decoration that grants\r\nthe Punishing Draw skill.",
# ```
# </details>
#
# #### df_deco_ids
# |id|name|description|
# |-|-|-|
# |Accessory_ACC_130724024|Attack Jewel [1]|A decoration that grants the Attack Boost skill.|
# |Accessory_ACC_m1843593600|Attack Jewel II [2]|A decoration that grants the Attack Boost skill.|
# |Accessory_ACC_280205024|Attack Jewel III [3]|A decoration that grants the Attack Boost skill.|
# |Accessory_ACC_m451614112|Expert Jewel [1]|A decoration that grants the Critical Eye skill.|
# |Accessory_ACC_248848256|Expert Jewel II [2]|A decoration that grants the Critical Eye skill.|

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/Accessory.msg.23.json'

df = json_to_df(url,['entries'])
df = parse_id_name_exp(df,'EXP_')

df_deco_ids = df.copy()

df_deco_ids.head()
# df_deco_ids.to_excel('deco.xlsx')
# Out:
#                           id                                guid_n  \
# 0    Accessory_ACC_130724024  56bff7fd-6ef8-4038-9ce7-006a0fdc88a1
# 1  Accessory_ACC_m1843593600  f559d3b8-44ba-44c7-8b0d-68622cb42e5e
# 2    Accessory_ACC_280205024  40d8ce15-1a4c-4b0a-837d-9dbaf1a5b80f
# 3   Accessory_ACC_m451614112  e9b426cb-e53d-47fe-989f-81c4870d21de
# 4    Accessory_ACC_248848256  acf0fecc-b210-4f88-b359-86d2390d5bbb
#
#                    name                                guid_d  \
# 0      Attack Jewel [1]  abb148ea-836c-4a2a-9cb8-5b74ab3c845c
# 1   Attack Jewel II [2]  e8c23984-96cb-4572-98a0-25103e2f05f8
# 2  Attack Jewel III [3]  4a37c8c6-2b2c-459c-a2a0-012b2aaa94fd
# 3      Expert Jewel [1]  da14a34b-9a23-4235-8d04-36fdb337f739
# 4   Expert Jewel II [2]  b572c525-8a62-4158-bc98-0b9fdc417cf2
#
#                                         description
# 0  A decoration that grants the Attack Boost skill.
# 1  A decoration that grants the Attack Boost skill.
# 2  A decoration that grants the Attack Boost skill.
# 3  A decoration that grants the Critical Eye skill.
# 4  A decoration that grants the Critical Eye skill.

# %% [markdown]
# ### Deco Skills
# #### Source
# natives/STM/GameDesign/Common/Equip/AccessoryData.user.3.json
#
# <details>
#
# ```
#     "app.user_data.AccessoryData": {
#         "Values": [
#             {
#                 "app.user_data.AccessoryData.cData": {
#                     "_Index": 0,
#                     "_AccessoryId": {
#                         "app.EquipDef.ACCESSORY_ID_Serializable": {
#                             "_Value": "[130724024]ACC_ID_0000"
#                             }
#                     },
#                     "_Name": "56bff7fd-6ef8-4038-9ce7-006a0fdc88a1",
#                     "_Explain": "abb148ea-836c-4a2a-9cb8-5b74ab3c845c",
#                     "_AccessoryType": {
#                         "app.EquipDef.ACCESSORY_TYPE_Serializable": {
#                             "_Value": "[-1638455296]ACC_TYPE_00"
#                         }
#                     },
#                     "_SortId": 101,
#                     "_Rare": {
#                         "app.ItemDef.RARE_Serializable": {
#                             "_Value": "[16]RARE2"
#                         }
#                     },
#                     "_IconColor": "[4]I_PINK",
#                     "_Price": 150,
#                     "_SlotLevelAcc": {
#                         "app.EquipDef.SlotLevel_Serializable": {
#                             "_Value": "[1]Lv1"
#                         }
#                     },
#                     "_Skill": [
#                         {
#                             "app.HunterDef.Skill_Serializable": {
#                                 "_Value": "[1]HunterSkill_000"
#                             }
#                         },
#                         {
#                             "app.HunterDef.Skill_Serializable": {
#                                 "_Value": "[0]NONE"
#                             }
#                         }
#                     ],
#                     "_SkillLevel": [
#                         1,
#                         0
#                     ]
#                 }
#             },
# ```
# </details>
#
# #### df

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/AccessoryData.user.3.json'

df = json_to_df(url,['app.user_data.AccessoryData','_Values'])
df.columns = df.columns.str.replace('app.user_data.AccessoryData.cData._','')

#fill names and descriptions
dict_ = dict(zip(df_deco_ids['guid_n'],df_deco_ids['name']))
df['Name'] = df['Name'].replace(dict_)
dict_ = dict(zip(df_deco_ids['guid_d'],df_deco_ids['description']))
df['Explain'] = df['Explain'].replace(dict_)

#deco size
df.rename(columns={'SlotLevelAcc.app.EquipDef.SlotLevel_Serializable._Value':'deco_size'}, inplace=True)
df['deco_size'] = df['deco_size'].str.extract(r'\[(.*?)\]').astype(int)

# skills
dict_ = dict(zip(df_common_skills['common_hunter_id'], df_common_skills['name']))
df = split_skills(df,replacement_dict=dict_)


# Rarity Clean

# Accessory Type Clean
dict_ = {'[-1638455296]ACC_TYPE_00':'Weapon',
         '[1842954880]ACC_TYPE_01':'Armor'}
df['AccessoryType.app.EquipDef.ACCESSORY_TYPE_Serializable._Value'] = df['AccessoryType.app.EquipDef.ACCESSORY_TYPE_Serializable._Value'].replace(dict_)

#rename
df.rename(columns={'AccessoryId.app.EquipDef.ACCESSORY_ID_Serializable._Value':'deco_id',
                   'AccessoryType.app.EquipDef.ACCESSORY_TYPE_Serializable._Value':'deco_type',
                   'Rare.app.ItemDef.RARE_Serializable._Value':'rarity',
                   'Name':'name',
                   'Explain':'description'},inplace=True)

df_decos = df[['deco_id','name','deco_type','rarity','deco_size','skill_1','skill_1_lv','skill_2','skill_2_lv']].copy()
df_decos.reset_index(drop=True, inplace=True)

df_decos.head()
df_decos.to_excel('wilds_decos.xlsx')

# %% [markdown]
# ### Deco Other
# #### Source
#
# natives/STM/GameDesign/Common/Equip/AccessoryJudgeData.user.3.json
#
# <details>
#
# ```
#     "app.user_data.AccessoryJudgeData": {
#         "_Values": [
#             {
#                 "app.user_data.AccessoryJudgeData.cData": {
#                     "_Index": 0,
#                     "_AccessoryId": {
#                         "app.EquipDef.ACCESSORY_ID_Serializable": {
#                             "_Value": "[130724024]ACC_ID_0000"
#                         }
#                     },
#                     "_Probability": [
#                         1,
#                         0,
#                         0,
#                         0,
#                         0
#                     ]
#                 }
#             },
# ```
# </details>
#
# natives/STM/GameDesign/Common/Equip/AccessoryRankJudgeData.user.3.json
#
# <details>
#
# ```
#     "app.user_data.AccessoryRankJudgeData": {
#         "_Values": [
#             {
#                 "app.user_data.AccessoryRankJudgeData.cData": {
#                     "_Index": 0,
#                     "_ItemId": {
#                         "app.ItemDef.ID_Serializable": {
#                             "_Value": "[619]ITEM_0645"
#                         }
#                     },
#                     "_AccessoryType": {
#                         "app.EquipDef.ACCESSORY_TYPE_Serializable": {
#                             "_Value": "[-1638455296]ACC_TYPE_00"
#                         }
#                     },
#                     "_Probability": [
#                         100,
#                         0,
#                         0,
#                         0,
#                         0
#                     ]
#                 }
#             },
# ```
# </details>
#
# natives/STM/GameDesign/Text/Excel_Equip/AccessoryData.msg.23.json
#
# <details>
#
# ```
# "entries": [
#     {
#       "name": "AccessoryData_ACC_EXP_130724024",
#       "guid": "443d9dba-6ecc-4c09-9540-6bc5307d186e",
#       "crc?": 3624618213,
#       "hash": 4289862584,
#       "attributes": [],
#       "content": [
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         ""
#       ]
#     },
#     {
#       "name": "AccessoryData_ACC_130724024",
#       "guid": "4f347e66-0474-402f-9bb3-f3c1516fdb91",
#       "crc?": 3865111821,
#       "hash": 669220903,
#       "attributes": [],
#       "content": [
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         "",
#         ""
#       ]
#     },
# ```
#
# </details>

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/AccessoryJudgeData.user.3.json'

url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/AccessoryRankJudgeData.user.3.json'

url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/AccessoryData.msg.23.json'

# %% [markdown]
# ## Amulets
# ### Amulet IDs
# #### Source
# natives/STM/GameDesign/Text/Excel_Equip/Amulet.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": Amulet_34
#     "content": Defense Charm II
#     "name": Amulet_EXP34
#     "content": A charm that grants the Defense Boost skill
# ```
# </details>
#
# #### df

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/Amulet.msg.23.json'

df = json_to_df(url,['entries'])
df = parse_id_name_exp(df,'EXP')

df_amulet_ids = df.copy()

df_amulet_ids.head()
# Out:
#          id                                guid_n                name  \
# 0  Amulet_1  e33f2711-f784-4030-92d8-062905b76265    Marathon Charm I
# 1  Amulet_2  bc7cbc9c-8288-4b6a-a237-7efc0a7bc013   Marathon Charm II
# 2  Amulet_3  b760fced-112e-4028-b9c6-247f73c2bd9a  Marathon Charm III
# 3  Amulet_4  557be166-ff64-4219-aa8f-b5decf7da225     Fitness Charm I
# 4  Amulet_5  3419f639-f057-413f-b0b4-43680aa70ed3    Fitness Charm II
#
#                                  guid_d  \
# 0  e3413820-fe5d-4397-8024-4fe212902582
# 1  c9785786-2d48-4a7b-a184-11761fd32962
# 2  e3eb9098-1f35-427b-b848-ad0e3709b5cc
# 3  85560730-3118-4eff-bf09-be2f01728569
# 4  5b8ed7c2-7b8e-4402-9e95-a00e7a261351
#
#                                       description
# 0  A charm that grants the Marathon Runner skill.
# 1  A charm that grants the Marathon Runner skill.
# 2  A charm that grants the Marathon Runner skill.
# 3     A charm that grants the Constitution skill.
# 4     A charm that grants the Constitution skill.

# %% [markdown]
# ### Amulet Other
# #### Source
#
# natives/STM/GameDesign/Common/Equip/AmuletData.user.3.json
#
# <details>
#
# ```
#     "app.user_data.AmuletData": {
#         "_Values": [
#             {
#                 "app.user_data.AmuletData.cData": {
#                     "_Index": 0,
#                     "_DataId": 1,
#                     "_Lv": 1,
#                     "_AmuletType": {
#                         "app.ArmorDef.AmuletType_Serializable": {
#                             "_Value": "[886754368]AT_0000"
#                         }
#                     },
#                     "_ModelId": 1,
#                     "_AmuletColor": {
#                         "app.ArmorDef.AmuletColorType_Serializable": {
#                             "_Value": "[-1310802816]AMYLET_COLOR_TYPE_00"
#                         }
#                     },
#                     "_NeedEffect": false,
#                     "_Name": "e33f2711-f784-4030-92d8-062905b76265",
#                     "_Explain": "e3413820-fe5d-4397-8024-4fe212902582",
#                     "_SortId": 88,
#                     "_Rare": {
#                         "app.ItemDef.RARE_Serializable": {
#                             "_Value": "[15]RARE3"
#                         }
#                     },
#                     "_IconColor": "[0]I_NONE",
#                     "_Price": 1500,
#                     "_Skill": [
#                         {
#                             "app.HunterDef.Skill_Serializable": {
#                                 "_Value": "[-682586176]HunterSkill_024"
#                             }
#                         },
#                         {
#                             "app.HunterDef.Skill_Serializable": {
#                                 "_Value": "[0]NONE"
#                             }
#                         },
#                         {
#                             "app.HunterDef.Skill_Serializable": {
#                                 "_Value": "[0]NONE"
#                             }
#                         }
#                     ],
#                     "_SkillLevel": [
#                         1,
#                         0,
#                         0
#                     ]
#                 }
#             },
# ```
# </details>
#
# natives/STM/GameDesign/Catalog/00_00/Data/AmuletColorData.user.3.json
#
# <details>
#
# ```
#     "app.user_data.AmuletColorData.cEntry": {
#         "_Key": "[2]SKILL_0001",
#         "STRUCT__Value__Rgba": {
#             "x": 0.42352942,
#             "y": 0.19607843,
#             "z": 0.87058824,
#             "w": 1.0
#         }
# ```
# </details>

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/AmuletData.user.3.json'

df = json_to_df(url,['app.user_data.AmuletData','_Values'])
df.columns = df.columns.str.replace('app.user_data.AmuletData.cData._','')

# name and description
dict_ = dict(zip(df_amulet_ids['guid_n'],df_amulet_ids['name']))
df['Name'] = df['Name'].replace(dict_)
dict_ = dict(zip(df_amulet_ids['guid_d'],df_amulet_ids['description']))
df['Explain'] = df['Explain'].replace(dict_)

# skills
dict_ = dict(zip(df_common_skills['common_hunter_id'], df_common_skills['name']))
df = split_skills(df,replacement_dict=dict_)

#rename
df.rename(columns={'AmuletType.app.ArmorDef.AmuletType_Serializable._Value':'amulet_id',
                   'Rare.app.ItemDef.RARE_Serializable._Value':'rarity',
                   'Name':'name',
                   'Explain':'description'},inplace=True)

df_amulet = df[['amulet_id','name','description','Lv','NeedEffect','rarity','skill_1','skill_1_lv','skill_2','skill_2_lv','skill_3','skill_3_lv']].copy()

df_amulet.head()
df_amulet.to_excel('wilds charms.xlsx')

# %% [markdown]
# ### RNG Amulets
#
# #### Source
#
# natives/STM/GameDesign/Common/Equip
#
# AmuletRankJudge.user.3.json
#     Rarity Chance
# MakaAmuletExchangeTable.user.3.json
#     Item IDs for material exchange
# MakaAmuletPointTable.user.3.json
#     Melding Costs
# RandomAmuletAccSlot.user.3.json
#     Slot Possibilities (and points)
# RandomAmuletLotSkillTable.user.3.json
#     Skill Possibilities (and points)
# RandomAmuletPtTable.user.3.json

# %%
head = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/'
tail = '.user.3.json'
body = 'AmuletRankJudge'

df = json_to_df(head + body + tail, ['app.user_data.' + body, '_Values'])
df.columns = df.columns.str.replace('app.user_data.'+body+'.cData._','')

df.to_excel('amulet/'+body+'.xlsx')

# %%
head = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/'
tail = '.user.3.json'
body = 'RandomAmuletAccSlot'

df = json_to_df(head + body + tail, ['app.user_data.' + body, '_Values'])
df.columns = df.columns.str.replace('app.user_data.'+body+'.cData._','')

# Accessory Type Clean
dict_ = {'[-1638455296]ACC_TYPE_00':'Weapon',
         '[1842954880]ACC_TYPE_01':'Armor'}

df['SlotType01'] = df['SlotType01'].replace(dict_)
df['SlotType02'] = df['SlotType02'].replace(dict_)
df['SlotType03'] = df['SlotType03'].replace(dict_)

# Deco Size Clean
df['SlotLevel01'] = df['SlotLevel01'].str.extract(r'\[(.*?)\]').astype(int)
df['SlotLevel02'] = df['SlotLevel02'].str.extract(r'\[(.*?)\]').astype(int)
df['SlotLevel03'] = df['SlotLevel03'].str.extract(r'\[(.*?)\]').astype(int)

df.to_excel('amulet/'+body+'.xlsx')

# %%
head = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/'
tail = '.user.3.json'
body = 'RandomAmuletLotSkillTable'

df = json_to_df(head + body + tail, ['app.user_data.' + body, '_Values'])
df.columns = df.columns.str.replace('app.user_data.'+body+'.cData._','')

# Skill Name
dict_ = dict(zip(df_common_skills['common_hunter_id'], df_common_skills['name']))
df[['SkillType']] = df[['SkillType']].replace(dict_)

# df.head()
df.to_excel('amulet/'+body+'.xlsx')

# %%
head = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/'
tail = '.user.3.json'
body = 'RandomAmuletPtTable'

df = json_to_df(head + body + tail, ['app.user_data.' + body, '_Values'])
df.columns = df.columns.str.replace('app.user_data.'+body+'.cData._','')

# Rarity rename
dict_ = {'[-1608406656]AT_0189':'RARE[4]',
         '[837371776]AT_0190':'RARE[5]',
         '[-1382563840]AT_0191':'RARE[6]',
         '[353607840]AT_0192':'RARE[7]'}
df.rename(columns={'AmuletType.app.ArmorDef.AmuletType_Serializable._Value':'Rarity'}, inplace=True)
df[['Rarity']]=df[['Rarity']].replace(dict_)


df.to_excel('amulet/'+body+'.xlsx')

# %% [markdown]
# ## Weapons

# %% [markdown]
# ### Weapon Text
# #### Source

# %%
head = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/'
tail = '.msg.23.json'
dict_df_weap_ids = {}

for weap,abbr in dict_weap_names.items():
    df = json_to_df(head + weap + tail ,['entries'])
    df = parse_id_name_exp(df, 'EXP')

    #shove into dict
    dict_df_weap_ids[abbr]=df.copy()

dict_df_weap_ids['hh'].head()
# Out:
#           id                                guid_n           name  \
# 0  Whistle_1  88a76352-1055-4e69-8650-6dbb641795ee    Hope Horn I
# 1  Whistle_2  300a4735-c0c4-4662-8c2e-a80e02b405ec   Hope Horn II
# 2  Whistle_3  9a24fea5-ccfc-4d69-9c6b-83cb3908b545  Hope Horn III
# 3  Whistle_4  bda74d0a-9f0c-4a6e-8022-c06703bf83f6   Hope Horn IV
# 4  Whistle_5  e6eb8aa5-bae5-42b5-b9aa-0fc33ea2e2b6    Hope Horn V
#
#                                  guid_d  \
# 0  56733819-8573-4ccb-8835-fbae2e48a625
# 1  06bda6d7-5e7d-42be-bf7f-e17dac875e13
# 2  0ec26983-ec1f-4b01-ae61-50717e402130
# 3  ee50ecd8-d328-4983-afd9-284e3772566a
# 4  062f67b7-c2ff-4b1e-8a17-96f258a70b75
#
#                                          description
# 0  A hunting horn made specifically for the exped...
# 1  A hunting horn made specifically for the exped...
# 2  A hunting horn made specifically for the exped...
# 3  A hunting horn made specifically for the exped...
# 4  A hunting horn made specifically for the exped...

# %% [markdown]
# ### Weapon Data

# %%
head = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Weapon/'
tail = '.user.3.json'

# output dict
dict_df_weap_data = {}

# column rename
dict_weap_col_rename = {'Rare.app.ItemDef.RARE_Serializable._Value':'rarity',
                        'Critical':'affinity',
                        'Attribute.app.WeaponDef.ATTR_Serializable._Value':'attribute_type',
                        'SubAttribute.app.WeaponDef.ATTR_Serializable._Value':'subattribute_type',
                        'RodInsectLv.app.WeaponDef.ROD_INSECT_LV_Serializable._Value':'kinsect_lv',
                        # 'Wp05UniqueType.app.Wp05Def.UNIQUE_TYPE_Serializable._Value':'song_list',
                        # 'Wp05MusicSkillHighFreqType.app.Wp05Def.WP05_MUSIC_SKILL_HIGH_FREQ_TYPE_Serializable._Value':'echo_wave',
                        # 'Wp05HibikiSkillType.app.Wp05Def.WP05_HIBIKI_SKILL_TYPE_Serializable._Value':'bubble_buff',
                        'MainShell.app.MainShellType.TYPE_Serializable._Value':'',
                        # 'Wp08BinType':'phial',
                        # 'Wp08BinValue':'phial_val',
                        'Wp09BinType':'',
                        'Wp13SpecialAmmo.app.Wp13Def.SPECIAL_AMMO_TYPE_Serializable._Value':'',
                        'EnergyEfficiency.app.EnergyEfficiencyType.TYPE_Serializable._Value':'efficiency',
                        'AmmoStrength.app.AmmoStrengthType.TYPE_Serializable._Value':'am_str',
                        'EnergyShellTypeNormal.app.BowgunEnergyShellType.NORMAL_Serializable._Value':'eshell_normal',
                        'EnergyShellTypePower.app.BowgunEnergyShellType.POWER_Serializable._Value':'eshell_power',
                        'EnergyShellTypeWeak.app.BowgunEnergyShellType.WEAK_Serializable._Value':'eshell_weak',
                        }

# weapon specificity
dict_weap_cols = {'generic':['id','name','description',''],
                  'hh':{'Wp05UniqueType.app.Wp05Def.UNIQUE_TYPE_Serializable._Value':'song_list',
                        'Wp05MusicSkillHighFreqType.app.Wp05Def.WP05_MUSIC_SKILL_HIGH_FREQ_TYPE_Serializable._Value':'echo_wave',
                        'Wp05HibikiSkillType.app.Wp05Def.WP05_HIBIKI_SKILL_TYPE_Serializable._Value':'bubble_buff'},
                  'swaxe':{'Wp08BinType':'phial',
                           'Wp08BinValue':'phial_val'},
                  'cb':['Wp09BinType'],
                  'hbg':[],
                  'lbg':[],
                  'ig':['kinsect_lv']
                  }

#tenative HH stuff:
hh_song_header = ['Song 1','Song 2','Song 3','Song 4','Song 5','Song 6','Song 7','Song 8','Song 9','Song 10']
hh_songs = {'[-1373429760]TYPE_0':['Self-Improvement','Attack Up (S)','Defense Up (S)','Wind Pressure Negated','Sonic Barrier','Echo Wave','Resounding Melody','0','0','0'],
            '[1244670208]TYPE_1':['Self-Improvement','Attack Up (L)','Defense Up (L)','Wind Pressure Negated','Sonic Barrier','Echo Wave','Resounding Melody','0','0','0'],
            '[1440765696]TYPE_2':['Self-Improvement','Attack Up (S)','Earplugs (S)','Aquatic/Oilsilt Mobility','Environment Damage Negated','Echo Wave','Offset Melody','0','0','0'],
            '[-223199088]TYPE_3':['Self-Improvement','Attack Up (L)','Earplugs (S)','Muck Resistance','Environmental Damage Negated','Echo Wave','Offset Melody','0','0','0'],
            '[-1139926272]TYPE_4':['Self-Improvement','Attack Up (S)','Fire Resistance (S)','Sonic Waves','Echo Wave','Offset Melody','0','0','0','0'],
            '[-2100493056]TYPE_5':['Self-Improvement','Attack Up (S)','Fire Res (L)','Sonic Waves','Echo Attack','Offset Melody','0','0','0','0'],
            '[-1750468608]TYPE_6':['Self-Improvement','Attack Up (L)','Health Recovery (S)','Recovery Speed (L)','Echo Wave','Melody of Life','0','0','0','0'],
            '[-683105216]TYPE_7':['Self-Improvement','Attack Up (L)','Defense Up (L)','Wind Pressure Negated','Sonic Barrier','Echo Wave','Resounding Melody','0','0','0'],
            '[1880695040]TYPE_8':['Self-Improvement','Stamina Use Reduced (S)','Defense Up (S)','Wind Pressure Negated','Sonic Barrier','Echo Wave','Offset Melody','0','0','0'],
            '[-1639516416]TYPE_9':['Self-Improvement','Stamina Use Reduced (L)','Defense Up (L)','Stun Resistance','Wind Pressure Negated','Sonic Barrier','Echo Wave','Offset Melody','0','0'],
            '[683699392]TYPE_10':['Self-Improvement','Stamina Use Reduced (S)','Defense Up (S)','Ice Resistance (S)','Sonic Waves','Echo Wave','Resounding Melody','0','0','0'],
            '[-1903484928]TYPE_11':['Self-Improvement','Stamina Use Reduced (L)','Defense Up (L)','Ice Res (L)','All Wind Pressure Negated','Sonic Waves','Echo Wave','Resounding Melody','0','0'],
            '[-406902816]TYPE_12':['Self-Improvement','Health Recovery (S)','Health Recovery (S) + Antidote','Stamina Use Reduced (S)','Defense Up (S)','Wind Pressure Negated','Echo Wave','Melody of Life','0','0'],
            '[-230971504]TYPE_13':['Self-Improvement','Health Recovery (S)','Health Recovery (M) + Antidote','Stamina Use Reduced (L)','Defense Up (L)','Wind Pressure Negated','Echo Wave','Melody Of Life','0','0'],
            '[1172300160]TYPE_14':['Self-Improvement','Attack and Defense Up (S)','Defense Up (L)','All Wind Pressure Negated','Stamina Use Reduced (L)','Echo Wave','Offset Melody','0','0','0'],
            '[-1370854016]TYPE_15':['Self-Improvement','Health Recovery (S)','Health Recovery (M)','Earplugs (S)','Echo Wave','Melody of Life','0','0','0','0'],
            '[-499568608]TYPE_16':['Self-Improvement','Health Recovery (S)','Health Recovery (L)','Earplugs (L)','Echo Wave','Melody Of Life','0','0','0','0'],
            '[-140090384]TYPE_17':[],
            '[-147232096]TYPE_18':['Self-Improvement','Elem Attack Boost','Water Res (L)','Dragon Res (L)','Tremors Negated','Paralysis Negated','Sonic Waves','Melody Of Life','0','0'],
            '[16342309]TYPE_19':['Self-Improvement','Status Attack Up','Divine Protection','All Ailments Negated','Echo Wave','Offset Melody','0','0','0','0'],
            '[-110447472]TYPE_20':['Self-Improvement','Health Recovery (S)','Recovery Speed (S)','Thunder Resistance (S)','Sonic Waves','Echo Wave','Offset Melody','0','0','0'],
            '[627102912]TYPE_21':['Self-Improvement','Elem Attack Boost','Recovery Speed (S)','Health Recovery (S)','Divine Protection','Thunder Res (L)','Sonic Waves','Echo Waves','Offset Melody','0'],
            '[1734782976]TYPE_22':['Self-Improvement','Affinity Up (S) + Health Recovery (S)','Earplugs (L)','Health Recovery (S)','Echo Waves','Melody Of Life','0','0','0','0'],
            '[-573176704]TYPE_23':[],
            '[1098587136]TYPE_24':[],
            '[929404736]TYPE_25':[],
            '[-67036184]TYPE_26':[],
            '[785515840]TYPE_27':[],
            '[-526658144]TYPE_28':[],
            '[-616761024]TYPE_29':[],
            '[1705688832]TYPE_30':[]
            }


for weap,abbr in dict_weap_names.items():
    df = json_to_df(head + weap + tail, ['app.user_data.WeaponData','_Values'])
    df.columns = df.columns.str.replace('app.user_data.WeaponData.cData._','')

    # rename proper weapon column
    df_2 = df.loc[0, dict_weap_names.keys()]
    mask = ~df_2.str.contains('INVALID')
    df_1 = df_2.index[mask]
    # if len(df_1) == 1:
    df = df.rename(columns={df_1[0]: 'id'})

    # fill name & detail
    dict_ = dict(zip(dict_df_weap_ids[abbr]['guid_n'], dict_df_weap_ids[abbr]['name']))
    df['Name'] = df['Name'].replace(dict_)
    dict_ = dict(zip(dict_df_weap_ids[abbr]['guid_d'], dict_df_weap_ids[abbr]['description']))
    df['Explain'] = df['Explain'].replace(dict_)

    # skill digestion
    dict_ = dict(zip(df_common_skills['common_hunter_id'], df_common_skills['name']))
    df = split_skills(df,replacement_dict=dict_)

    # Slot digestion
    df = split_slots(df,'SlotLevel')

    # Sharpness digestion
    df_1 = ['red','orange','yellow','green','blue','white','purple']
    for i,e in enumerate(df_1):
        df[e] = df['SharpnessValList'].str[i].astype(int)
    df = df.drop('SharpnessValList', axis=1)

    # Attribute digestion
    

    df.rename(columns={'Rare.app.ItemDef.RARE_Serializable._Value':'rarity',
                       'Critical':'affinity',
                       'Attribute.app.WeaponDef.ATTR_Serializable._Value':'attribute_type',
                       'SubAttribute.app.WeaponDef.ATTR_Serializable._Value':'subattribute_type',
                       'RodInsectLv.app.WeaponDef.ROD_INSECT_LV_Serializable._Value':'kinsect_lv',
                       'Wp05UniqueType.app.Wp05Def.UNIQUE_TYPE_Serializable._Value':'hh_unique',
                       'Wp05MusicSkillHighFreqType.app.Wp05Def.WP05_MUSIC_SKILL_HIGH_FREQ_TYPE_Serializable._Value':'hh_highfreq',
                       'Wp05HibikiSkillType.app.Wp05Def.WP05_HIBIKI_SKILL_TYPE_Serializable._Value':'hh_hibiki',
                       'Wp08BinType':'swaxe_phial',
                       'Wp08BinValue':'swaxe_phial_val'}, inplace=True)
    
    df = df[['id', 'Name',
            #  'Explain',
             'rarity',
             'Attack',
             'Defense',
             'affinity',
             'attribute_type',
             'AttributeValue',
             'subattribute_type',
             'SubAttributeValue',
             'Slot 1',
             'Slot 2',
             'Slot 3',
             'kinsect_lv',
            #  'phial',
            #  'phial_val', 
             'Wp09BinType',
             'hh_unique',
             'hh_highfreq',
             'hh_hibiki',
             'MainShell.app.MainShellType.TYPE_Serializable._Value',
             'ShellLv',
             'ShellNum',
             'RapidShellNum',
             'IsRappid',
             'CustomizePattern',
             'Wp13SpecialAmmo.app.Wp13Def.SPECIAL_AMMO_TYPE_Serializable._Value',
             'EnergyEfficiency.app.EnergyEfficiencyType.TYPE_Serializable._Value',
             'AmmoStrength.app.AmmoStrengthType.TYPE_Serializable._Value',
             'EnergyShellTypeNormal.app.BowgunEnergyShellType.NORMAL_Serializable._Value',
             'EnergyShellTypePower.app.BowgunEnergyShellType.POWER_Serializable._Value',
             'EnergyShellTypeWeak.app.BowgunEnergyShellType.WEAK_Serializable._Value',
            #  'DispSilencer',
            #  'DispBarrel',
            #  'isLoadingBin',
            #  'SharpnessValList',
             'red',
             'orange',
             'yellow',
             'green',
             'blue',
             'white',
             'purple',
             'TakumiValList',
             'Wp07ShellType.app.Wp07Def.SHELL_TYPE_Serializable._Value',
             'Wp07ShellLv.app.Wp07ShellLevel.SHELL_LV_Serializable._Value',
             'skill_1',
             'skill_1_lv',
             'skill_2',
             'skill_2_lv',
             'skill_3',
             'skill_3_lv',
             'skill_4',
             'skill_4_lv'
             ]]



    dict_df_weap_data[abbr] = df.copy()

# dict_df_weap_data['ls']

# %%
dict_df_weap_ids['lbg']
# Out:
#                 id                                guid_n  \
# 0    LightBowgun_1  0e85bf84-e3f2-48b8-b7e9-fdf9f57358a0
# 1    LightBowgun_2  22f2112a-165b-43e0-8c5e-200cf5ee8f59
# 2    LightBowgun_3  720c23a5-ce88-4aea-9abf-b8f440599481
# 3    LightBowgun_4  9659a6ba-de59-4406-abce-99b56a7d1ad2
# 4    LightBowgun_5  77ef492f-52f0-45b4-babf-2dac150356cc
# ..             ...                                   ...
# 72  LightBowgun_62  c65ecebc-46f3-4882-977c-b0f895f5f95d
# 73  LightBowgun_63  e73363f5-6c79-45c1-9024-6135e5e50506
# 74  LightBowgun_64  ff054a5c-60aa-4be6-a524-21385df3c717
# 75   LightBowgun_6  4280efb6-e526-4ccc-ab60-9cac19eadae1
# 76   LightBowgun_7  260a2b4f-9d44-4139-93e5-35a92aa0031f
#
#                      name                                guid_d  \
# 0            Hope Rifle I  bc4dfa49-8050-4f36-bf90-22dbced877d3
# 1           Hope Rifle II  3d6f64f2-b8e5-4f30-b45b-fb5d79832608
# 2          Hope Rifle III  b318f088-40ac-4d2e-9523-ecd57874cf42
# 3           Hope Rifle IV  9337579e-ea37-4b70-bc77-c79dac262b05
# 4            Hope Rifle V  e90c2295-9456-4450-a912-d02c29c472f0
# ..                    ...                                   ...
# 72   G. Veldian Impetum I  c5d5c124-3fb9-4215-90c0-330ac9074769
# 73  G. Veldian Impetum II  9cf65ef0-ffd0-4d66-9fd9-c11b712e73b3
# 74     G. Expiating Caius  7fb4da67-15a0-4a5f-9780-1dfc8fa1f3b9
# 75         Kut-Ku Anger I  b5e0c7ef-e35f-4f01-bc09-353f13b391d6
# 76        Kut-Ku Anger II  a87ca25f-c25d-4f4b-8424-e021d83789da
#
#                                           description
# 0   A light bowgun made specifically for the exped...
# 1   A light bowgun made specifically for the exped...
# 2   A light bowgun made specifically for the exped...
# 3   A light bowgun made specifically for the exped...
# 4   A light bowgun made specifically for the exped...
# ..                                                ...
# 72  A light bowgun made from Guardian spoils. It g...
# 73  A light bowgun made from Guardian spoils. It g...
# 74  An upgraded G. Veldian Impetum. It echoes fina...
# 75  A light bowgun fashioned to resemble the Yian ...
# 76  A light bowgun fashioned to resemble the Yian ...
#
# [77 rows x 5 columns]

# %%
dict_df_weap_data['bow'].to_excel('bow.xlsx')

# %%
leftovers:
'bow':'BowTree.user.3.json','cb':'ChargeAxeTree.user.3.json','gl':'GunLanceTree.user.3.json','ham':'HammerTree.user.3.json','hbg':'HeavyBowgunTree.user.3.json','lan':'LanceTree.user.3.json','lbg':'LightBowgunTree.user.3.json','gs':'LongSwordTree.user.3.json','ig':'RodTree.user.3.json','sns':'ShortSwordTree.user.3.json','swaxe':'SlashAxeTree.user.3.json','ls':'TachiTree.user.3.json','db':'TwinSwordTree.user.3.json','hh':'WhistleTree.user.3.json','kinsect':'RodInsectData.user.3.json'
# Out:
#   Cell In[24], line 1
#     leftovers:
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Weapon-Specific Data

# %% [markdown]
# #### HH Song List
#
# natives/STM/GameDesign/Common/Player/ActionGuide/HibikiData_Wp05.user.3.json
# https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Player/ActionGuide/HibikiData_Wp05.user.3.json
#
# natives/STM/GameDesign/Common/Player/ActionGuide/HighFreqData_Wp05.user.3.json
# https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Player/ActionGuide/HighFreqData_Wp05.user.3.json
#
# natives/STM/GameDesign/Text/Excel_Action/HibikiDataText_Wp05.msg.23.json
# https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Action/HibikiDataText_Wp05.msg.23.json
#
# natives/STM/GameDesign/Text/Excel_Action/HighFreqDataText_Wp05.msg.23.json
# https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Action/HighFreqDataText_Wp05.msg.23.json
#
# natives/STM/GameDesign/Facility/ArtianPerformanceData.user.3.json
# https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Facility/ArtianPerformanceData.user.3.json

# %% [markdown]
# ##### MusicSkillDataText_Wp05.msg.23.json
# natives/STM/GameDesign/Text/Excel_Action/MusicSkillDataText_Wp05.msg.23.json
#
# ###### df_song_ids

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Action/MusicSkillDataText_Wp05.msg.23.json'

df = json_to_df(url)
df = parse_id_name(df)

df_song_ids = df.copy()

# %% [markdown]
# ##### MusicSkillData_Wp05.user.3.json
# natives/STM/GameDesign/Common/Player/ActionGuide/MusicSkillData_Wp05.user.3.json
#
# ###### df_songs

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Player/ActionGuide/MusicSkillData_Wp05.user.3.json'

df = json_to_df(url,['app.user_data.MusicSkillData_Wp05','_Values'])
df.columns = df.columns.str.replace('app.user_data.MusicSkillData_Wp05.cData._','')
dict_ = dict(zip(df_song_ids['guid_n'],df_song_ids['name']))
df['MusicSkillName'] = df['MusicSkillName'].replace(dict_)

df_songs = df.copy()
# Out:
#     Index  \
# 0      33
# 1      39
# 2      30
# 3      18
# 4       4
# 5      38
# 6      34
# 7      24
# 8      40
# 9      35
# 10     32
# 11     41
# 12     22
# 13     11
# 14     26
# 15     37
# 16     31
# 17     27
# 18     19
# 19     46
# 20      1
# 21     47
# 22     25
# 23      7
# 24      2
# 25      8
# 26     17
# 27     20
# 28      9
# 29     43
# 30     44
# 31     23
# 32     15
# 33      3
# 34      5
# 35     21
# 36     42
# 37     29
# 38      0
# 39     10
# 40     16
# 41     12
# 42     13
# 43      6
# 44     14
# 45     36
# 46     45
# 47     28
#
#    MusicSkillType.app.Wp05Def.WP05_MUSIC_SKILL_TYPE_Serializable._Value  \
# 0                         [-1974724224]DISABLE_WIND_L
# 1                                  [-1611785856]SONIC
# 2                       [-1582363904]DISABLE_PARALYSE
# 3                        [-1496663168]ELEM_FIRE_DEF_L
# 4                     [-1429834368]HEAL_S_POISON_HEAL
# 5                   [-1384501504]DISABLE_ALL_ATTR_DMG
# 6                        [-1349504000]DISABLE_FOOTING
# 7                         [-1220568064]ELEM_ICE_DEF_L
# 8              [-1007463616]ALL_MUSIC_SKILL_EXTENSION
# 9                     [-995860096]DISABLE_TERRAIN_DMG
# 10                         [-971010560]DISABLE_WIND_S
# 11                      [-916822400]ATK_UP_S_DEF_UP_S
# 12                        [-814211904]ELEM_ELEC_DEF_L
# 13                               [-761535104]ATK_UP_L
# 14                      [-723016640]ELEM_DRAGON_DEF_L
# 15                   [-592732160]DISABLE_ALL_BAD_COND
# 16                           [-539417472]DISABLE_STUN
# 17                             [-498572352]EAR_PLUG_S
# 18                       [-363619680]ELEM_WATER_DEF_S
# 19              [-262396624]SP_PENETRATE_SOUND_ATTACK
# 20                                 [-198401488]HEAL_S
# 21                                 [-62895040]SP_HEAL
# 22                       [-55357592]ELEM_DRAGON_DEF_S
# 23                              [-52556308]HEAL_SPD_L
# 24                                  [-21850468]HEAL_M
# 25                                [61852696]STAMINA_S
# 26                         [120618040]ELEM_FIRE_DEF_S
# 27                        [260761120]ELEM_WATER_DEF_L
# 28                               [369188288]STAMINA_L
# 29                           [712401600]SOUND_BARRIER
# 30                              [774185280]HEAL_SHARP
# 31                          [796075584]ELEM_ICE_DEF_S
# 32                                [934242112]DEF_UP_L
# 33                                 [1071072832]HEAL_L
# 34                     [1107371904]HEAL_M_POISON_HEAL
# 35                        [1121529856]ELEM_ELEC_DEF_S
# 36                        [1129084032]CRT_UP_S_HEAL_S
# 37                          [1231601152]DISABLE_QUAKE
# 38                              [1323759744]SELF_BUFF
# 39                               [1330159872]ATK_UP_S
# 40                                  [1448648192]BLESS
# 41                            [1540980992]ELEM_ATK_UP
# 42                        [1545725184]BAD_COND_ATK_UP
# 43                             [1552335488]HEAL_SPD_S
# 44                               [1571208064]DEF_UP_S
# 45                            [1631480704]SUPER_ARMOR
# 46                  [2091877760]SP_PARRY_SOUND_ATTACK
# 47                             [2106785920]EAR_PLUG_L
#
#    IconType.app.IconDef.STATUS_Serializable._Value  \
# 0                                  [41]STATUS_0040
# 1                                  [76]STATUS_0075
# 2                                  [43]STATUS_0042
# 3                                  [50]STATUS_0049
# 4                                  [84]STATUS_0083
# 5                                  [59]STATUS_0058
# 6                                  [62]STATUS_0061
# 7                                  [56]STATUS_0055
# 8                                  [77]STATUS_0076
# 9                                  [63]STATUS_0062
# 10                                 [40]STATUS_0039
# 11                                      [0]INVALID
# 12                                 [54]STATUS_0053
# 13                                 [93]STATUS_0088
# 14                                 [58]STATUS_0057
# 15                                 [60]STATUS_0059
# 16                                 [42]STATUS_0041
# 17                                 [45]STATUS_0044
# 18                                 [51]STATUS_0050
# 19                                 [75]STATUS_0074
# 20                                 [84]STATUS_0083
# 21                                 [75]STATUS_0074
# 22                                 [57]STATUS_0056
# 23                                 [17]STATUS_0016
# 24                                 [84]STATUS_0083
# 25                                 [19]STATUS_0018
# 26                                 [49]STATUS_0048
# 27                                 [52]STATUS_0051
# 28                                 [19]STATUS_0018
# 29                                 [80]STATUS_0079
# 30                                 [79]STATUS_0078
# 31                                 [55]STATUS_0054
# 32                                 [92]STATUS_0089
# 33                                 [84]STATUS_0083
# 34                                 [84]STATUS_0083
# 35                                 [53]STATUS_0052
# 36                                 [78]STATUS_0077
# 37                                 [44]STATUS_0043
# 38                                 [38]STATUS_0037
# 39                                 [93]STATUS_0088
# 40                                 [48]STATUS_0047
# 41                                 [91]STATUS_0090
# 42                                 [90]STATUS_0091
# 43                                 [17]STATUS_0016
# 44                                 [92]STATUS_0089
# 45                                 [64]STATUS_0063
# 46                                 [75]STATUS_0074
# 47                                 [46]STATUS_0045
#
#                  MusicSkillName  SortID
# 0     All Wind Pressure Negated      34
# 1                   Sonic Waves      40
# 2             Paralysis Negated      31
# 3                  Fire Res (L)      19
# 4    Health Rec. (S) + Antidote       5
# 5                Blight Negated      39
# 6      Aquatic/Oilsilt Mobility      35
# 7                   Ice Res (L)      25
# 8           Extend All Melodies      41
# 9         Envir. Damage Negated      36
# 10        Wind Pressure Negated      33
# 11        Attack/Defense Up (S)      42
# 12              Thunder Res (L)      23
# 13                Attack Up (L)      12
# 14               Dragon Res (L)      27
# 15         All Ailments Negated      38
# 16                 Stun Negated      32
# 17                 Earplugs (S)      28
# 18                Water Res (S)      20
# 19            Resounding Melody      47
# 20          Health Recovery (S)       2
# 21               Melody of Life      48
# 22               Dragon Res (S)      26
# 23           Recovery Speed (L)       8
# 24          Health Recovery (M)       3
# 25      Stamina Use Reduced (S)       9
# 26                 Fire Res (S)      18
# 27                Water Res (L)      21
# 28      Stamina Use Reduced (L)      10
# 29                Sonic Barrier      44
# 30            Restore Sharpness      45
# 31                  Ice Res (S)      24
# 32               Defense Up (L)      16
# 33          Health Recovery (L)       4
# 34   Health Rec. (M) + Antidote       6
# 35              Thunder Res (S)      22
# 36  Affinity Up/Health Recovery      43
# 37              Tremors Negated      30
# 38             Self-Improvement       1
# 39                Attack Up (S)      11
# 40            Divine Protection      17
# 41            Elem Attack Boost      13
# 42             Status Attack Up      14
# 43           Recovery Speed (S)       7
# 44               Defense Up (S)      15
# 45            Knockback Negated      37
# 46                Offset Melody      46
# 47                 Earplugs (L)      29

# %% [markdown]
# ### Weapon Other
# #### Source
# natives/STM/GameDesign/Common/Equip/WeaponSeriesData.user.3.json
#
# <details>
#
# ```
# "app.user_data.WeaponSeriesData": {
#     "_Values": [
#         {
#             "app.user_data.WeaponSeriesData.cData": {
#                 "_Index": 6,
#                 "_Series": {
#                     "app.WeaponDef.SERIES_Serializable": {
#                         "_Value": "[-772890752]ID_007"
#                     }
#                 },
#                 "_Name": "49e1628e-a0ab-4301-a519-73819e97290e"
#             }
# ```
# </details>

# %%
https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/BowgunCustomizeItemData.user.3.json
https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/BowgunCustomizeData.user.3.json
https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Common/Equip/WeaponSeriesData.user.3.json

# %% [markdown]
# ## Misc
# ### Mantles
# #### Source
#
# natives/STM/GameDesign/Text/Excel_Equip/HunterActiveSkill.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": "HunterActiveSkill_3",
#     "content": [
#         "Continually restores health for\r\na period of time.",
# ```
# </details>
#
# Mantle names:
# - chained to item ids in natives/STM/GameDesign/Common/Equip/HunterActiveSkillData.user.3.json
# - chained to raw name in natives/STM/GameDesign/Common/Item/itemData.user.3.json
# - chained to content in natives/STM/GameDesign/Text/Excel_Data/Item.msg.23.json
#
# #### DF

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/HunterActiveSkill.msg.23.json'

with urllib.request.urlopen(url) as page:
    raw = json.load(page)
sect = raw.get('entries')
df = pd.json_normalize(sect)

# pull english names
df['content'] = df['content'].str[1]

# rename columns
df.rename(columns={'name':'id','content':'description'}, inplace=True)

# adjust descriptions
df['description'] = df['description'].str.replace(r'[\r\n]+', ' ', regex=True)


df_mantles = df[['id','description','guid']].copy()

df_mantles.head()

# %% [markdown]
# ### Meal Skills
# #### Source
# natives/STM/GameDesign/Text/Excel_Equip/MealSkill.msg.23.json
# <details>
#
# ```
# "entries": [
#     "name": "MealSkill_NAME_6",
#     "content": [
#         "Black Belt Meal (Lo)",
#     "name": "MealSkill_EXP_6",
#     "content": [
#         "回避などの固定でスタミナを\r\n消費する行動のスタミナ消費量が\r\n軽減される。",
#         "Reduces stamina depletion\r\nwhen performing stamina-draining\r\nmoves such as evading, etc.",
# ```
# </details>
#
# #### DF

# %%
url = 'https://raw.githubusercontent.com/dtlnor/MHWs-in-json/refs/heads/main/natives/STM/GameDesign/Text/Excel_Equip/MealSkill.msg.23.json'

with urllib.request.urlopen(url) as page:
    raw = json.load(page)
sect = raw.get('entries')
df = pd.json_normalize(sect)

# pull english names
df['content'] = df['content'].str[1]

#separate names and descriptions
df_1 = df[~df['name'].str.contains('EXP')].copy()
df_2 = df[df['name'].str.contains('EXP')].copy()

#normalize naming
df_1['name'] = df_1['name'].str.replace('NAME_','')
df_2['name'] = df_2['name'].str.replace('EXP_','')
df_1.rename(columns={'name':'id','content':'name'}, inplace=True)
df_2.rename(columns={'name':'id','content':'description'}, inplace=True)

#adjust descriptions
df_2['description'] = df_2['description'].str.replace(r'[\r\n]+', ' ', regex=True)

#merge into final
df_meal_skills = pd.merge(df_1[['id','name']], df_2[['id','description']], on='id', how='left')
df_meal_skills.reset_index(drop=True, inplace=True)

df_meal_skills.head()

# %% [markdown]
# ### NG Words
# #### Source
# natives/STM/GameDesign/Text/NGWord/
# - NGWordDataForMS.user.3.json
# - NGWordDataForName.user.3.json
# - NGWordDefault.user.3.json

# %% [markdown]
# sheet theft

# %%
# import pandas as pd
# url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQwtJ4Y6LJXQ9ORiNE_gTNQuMEQwabLS0lGeKTLPXb4WYHXJwLKDndC-cBl_KCBWQ/pubhtml#"
# df = pd.read_html(url, encoding="utf-8")
# df = df[0]
# df.columns = df.iloc[0]
# df = df[1:].reset_index(drop=True)

# df['Skill_ID'] = df['skillId']
# df['Skill'] = df['skillName']
# df['Skill_Type'] = df['skillCategory']
# df_skills = df[['Index','Skill_ID','Skill','Skill_Type']].copy()

# dict_skills = dict(zip(df_skills['Skill_ID'], df_skills['Skill']))
# # df.head()
# # df.to_excel("Skill_Names.xlsx")

# df = pd.read_excel("mhwilds/SkillData.user.3.xlsx")
# df['skillName'] = df['skillId'].replace(dict_skills)
# df.to_excel('mhwilds/SkillData.user.3.2.xlsx', index=False)
